// %% [markdown]
// # Lista exercicios 06

// %% [markdown]
// ## Siga as instruções de cada exercício e utilize a estrutura de desvio de fluxo if else e a classe Scanner para interagir com o usuário e realizar os procedimentos necessários.

// %% [markdown]
// 1 - Crie uma classe em Java solicitando ao usuário para insirir o valor total de uma compra e o tipo de cliente (regular ou especial). Se for cliente especial, conceda um desconto de 10% no valor total. Caso contrário, conceda um desconto de 5%. Em seguida, exiba o valor final após o desconto.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex01 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        double valorCompra, descontoEspecial, descontoRegular, valorFinalEspecial, valorFinalRegular;

		System.out.print("valor total da compra: "); // pede o valor da compra
		valorCompra = s.nextInt(); // declaração e inicialização da variável

        System.out.print("tipo de cliente (especial ou regular): "); // cliente regular ou especial
		String tipoCliente = s.next(); // declaração e inicialização da variável


        if (tipoCliente == "especial" ) {
            descontoEspecial = valorCompra * 0.1;
            valorFinalEspecial = valorCompra - descontoEspecial;
            System.out.println("Valor final da compra: " + valorFinalEspecial);
            
        } else {
            descontoRegular = valorCompra * 0.05;
            valorFinalRegular = valorCompra - descontoRegular;
            System.out.println("Valor final da compra: " + valorFinalRegular);
        } 

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// valor total da compra:
//  200
// tipo de cliente (especial ou regular):
//  especial
// Valor final da compra: 190.0
// null

// %% [markdown]
// 2 - Crie uma classe em Java que peça ao usuário para inserir um ano e verifique se é um ano bissexto ou não. Um ano bissexto é aquele que é divisível por 4, exceto os anos que são divisíveis por 100, a menos que sejam divisíveis por 400.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int ano;

		System.out.print("Insira um ano: "); // insere o ano
		ano = s.nextInt(); // declaração e inicialização da variável

        if (ano % 4 == 0 && ano % 100 != 0 ) { //se for divisível por 4 mas não por 100
            
            System.out.println("É um ano bissexto.");
            
        } else if (ano % 100 == 0 && ano % 400 == 0) { // se for divisívl por 100 mas por 400 também
            System.out.println("É um ano bissexto.");
        } else {
             System.out.println("Não é um ano bissexto.");
        }

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Insira um ano:
//  2024
// É um ano bissexto.
// null

// %% [markdown]
// 3 - Crie uma classe em Java que solicite ao usuário para inserir três números e ordene-os em ordem crescente utilizando estruturas de if else.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int a, b, c, menor, medio, maior;

		System.out.print("Insira um valor: "); // pede o valor 
		a = s.nextInt(); // declaração e inicialização da variável

        System.out.print("Insira um segundo valor: "); // pede o valor 
		b = s.nextInt(); // declaração e inicialização da variável

        System.out.print("Insira um terceiro valor: "); // pede o valor 
		c = s.nextInt(); // declaração e inicialização da variável

        menor = a;
        medio = b;
        maior = c;

        if (b < a && c > a && b < c) {
            menor = b;
            medio = a;
            maior = c;
        } else if (c < a && b < c && a > b) {
            menor = b;
            medio = c;
            maior = a; 
        } else if (c < b && b < a && a > c){
            menor = c;
            medio = b;
            maior = a;
        
        } else if (a < b && a < c && c < b) {
            menor = a;
            medio = c;
            maior = b;
        } else if (c < a && c < b && a < b) {
            menor = c;
            medio = a;
            maior = b;
        } else {
            menor = a;
            medio = b;
            maior = c;
        }

        System.out.println("Ordem crescente: " + menor + " " + medio + " " + maior);


		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Insira um valor:
//  12
// Insira um segundo valor:
//  3
// Insira um terceiro valor:
//  5
// Ordem crescente: 3 5 12
// null

// %% [markdown]
// 4 - Crie uma classe em Java que solicite uma letra do usuário e use if else para determinar se é uma vogal ou consoante.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        String letra;

		System.out.print("Insira uma letra: "); // insere a letra
		letra = s.next(); // declaração e inicialização da variável

        if (letra == "A") {
            System.out.println("É vogal.");
        } else if ( letra == "E") {
            System.out.println("É vogal.");
            
        } else if ( letra == "I") {
            System.out.println("É vogal.");
            
        } else if ( letra == "O") {
        System.out.println("É vogal.");
        
        } else if ( letra == "U") {
            System.out.println("É vogal.");
            
        } else {
             System.out.println("Não é vogal.");
        }

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Insira uma letra:
//  B
// Não é vogal.
// null

// %% [markdown]
// 5 - Crie uma classe em Java que peça ao usuário para inserir três valores que representem os lados de um triângulo. Use if else para determinar se é um triângulo equilátero, isósceles ou escaleno.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int a, b, c;

		System.out.print("primeiro lado: "); // insere o valor
		a = s.nextInt(); // declaração e inicialização da variável
        
        System.out.print("segundo lado: "); // insere o valor
		b = s.nextInt(); // declaração e inicialização da variável

		System.out.print("terceiro lado: "); // insere o valor
		c = s.nextInt(); // declaração e inicialização da variável


        // triangulo isosceles: dois iguais e um diferente
        // equilatero: todos os lados iguais
        // escaleno: todos diferentes

        if (a == b && a == c && b==c) {
            System.out.println("É um triângulo equilátero.");
        } else if (a != b && a!= c && b != c) {
            System.out.println("É um triângulo escaleno.");
        } else {
            System.out.println("É um triângulo isósceles.");
        }
		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// primeiro lado:
//  5
// segundo lado:
//  4
// terceiro lado:
//  5
// É um triângulo isósceles.
// null
