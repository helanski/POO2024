// %% [markdown]
// # Atividade 03

// %% [markdown]
// ## Crie uma classe em java capaz de imprimir o seu nome no console.

// %%
//public class Atv03 {

    //public static void main(String args[]){
        String nome = "Gabriele";
        System.out.println("Nome: " + nome); // imprime nome no console
   // }
//}
// Out:
// Nome: Gabriele
// null

// %% [markdown]
// ## Crie uma classe que efetue a leitura de um valor qualquer e exiba o seu respectivo valor na tabela ASCII.

// %%
// public class Atv03 {
        char valor = 'g';
        int ascii = valor; // java armazena automaticamente o valor ASCII de 'd' dentro da nova variável int 
    
        System.out.println("O valor ASCII de '" + valor  + "' é: " + ascii);
    // }

//}
// Out:
// O valor ASCII de 'g' é: 103
// null
