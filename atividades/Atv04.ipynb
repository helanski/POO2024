// %% [markdown]
// # Exercício 01
//
// <p style="text-align:justify;">
// Crie uma classe que efetue a leitura de um valor inteiro e outro real, exibindo-os no console.
// </p>

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex01 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados

		System.out.print("Digite um valor inteiro: "); // pede o valor inteiro
		int inteiro = s.nextInt(); // declaração e inicialização da variável
		System.out.println("O valor do inteiro digitado é = " + inteiro); // exibe valor do inteiro

        System.out.print("Digite um valor real: "); // pede o valor real
        double real = s.nextDouble(); // declaração e inicialização da variável
        System.out.println("O valor do real digitado é = " + real); // exibe valor do inteiro


        
		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Digite um valor inteiro:
//  5
// O valor do inteiro digitado é = 5
// Digite um valor real:
//  2.5
// O valor do real digitado é = 2.5
// null

// %% [markdown]
// # Exercício 02
//
// <p style="text-align:justify;">
// Crie uma classe que receba o valor de um produto e a porcentagem de desconto, calcule e mostre o valor do desconto e o valor do produto com o desconto.
// </p>
//
// - Observação: o valor do desconto é calculado por meio da fórmula:
//     valor do desconto = valor do produto * percentual de desconto / 100.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex02 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int produto, porcentagemDesconto, desconto, novoValor; // declara as variáveis

        System.out.print("Valor do produto: ");
		produto = s.nextInt(); // declaração e inicialização da variável

        System.out.print("Porcentagem do desconto: ");
		porcentagemDesconto = s.nextInt(); // declaração e inicialização da variável 

        desconto = (produto * porcentagemDesconto) / 100; // calcula o desconto
        novoValor = produto - desconto; // produto com o desconto

        System.out.println("Valor do desconto: " + desconto);
        System.out.println("Valor do produto com desconto : " + novoValor);

        
		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Valor do produto:
//  100
// Porcentagem do desconto:
//  10
// Valor do desconto: 10
// Valor do produto com desconto : 90
// null

// %% [markdown]
// # Exercício 03
//
// <p style="text-align:justify;">
// Crie uma classe que receba dois valores inteiros.
// </p>
//
// - O primeiro valor corresponde à quantidade de pontos do líder do campeonato brasileiro de futebol.
//
// - O segundo valor corresponde à quantidade de pontos do time lanterna.
//
// <p style="text-align:justify;">
// - Considerando que cada vitória vale 3 pontos, calcule o número de vitórias necessárias para que o time lanterna alcance (ou ultrapasse) o líder.
//
// - Por exemplo, supondo que as quantidades de ponto fornecidas sejam 40 e 22, então o número de vitórias apresentada na saída deverá ser 6, pois (40-22) / 3 = 6.
// </p>

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex03 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int pontosLider, pontosLanterna, numVitorias;

		System.out.print("Qt. de pontos do líder do campeonato: ");
		pontosLider = s.nextInt(); // declaração e inicialização da variável

        System.out.print("Qt. pontos do time lanterna: "); // pede o valor real
        pontosLanterna = s.nextInt(); // declaração e inicialização da variável

        numVitorias = (pontosLider - pontosLanterna) / 3;
        System.out.println("Número de vitórias necessárias para ultrapassar o líder: " + numVitorias);

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Qt. de pontos do líder do campeonato:
//  40
// Qt. pontos do time lanterna:
//  22
// Número de vitórias necessárias para ultrapassar o líder: 6
// null

// %% [markdown]
// # Exercício 04
// <p style="text-align:justify;">
// Crie uma classe que solicite ao usuário inserir dois inteiros, obtenha dele esses números e imprima sua soma, produto, diferença e quociente (divisão).
// </p>

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex04 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in); // prepara entrada de dados
        int valor1, valor2, soma, produto, diferenca, quociente;

		System.out.print("Primeiro valor: ");
		valor1 = s.nextInt(); // declaração e inicialização da variável

        System.out.print("Segundo Valor: "); // pede o valor real
        valor2 = s.nextInt(); // declaração e inicialização da variável

        soma = valor1 + valor2;
        System.out.println("Soma: " + soma);
        produto = valor1 * valor2;
        System.out.println("Produto: " + produto);
        diferenca = valor1 - valor2;
        System.out.println("Diferença: " + diferenca);
        quociente = valor1 / valor2;
        System.out.println("Quociente: " + quociente);

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Primeiro valor:
//  4
// Segundo Valor:
//  3
// Soma: 7
// Produto: 12
// Diferença: 1
// Quociente: 1
// null

// %% [markdown]
// # Exercício 05
//
// Declare uma classe para calcular o produto de três inteiros.
//
// Siga as instruções abaixo:
//
// 1. Crie um Scanner chamado input que leia valores a partir da entrada padrão.
// 2. Declare as variáveis x, y, z e result como tipo int.
// 3. Solicite que o usuário insira o primeiro inteiro.
// 4. Leia o primeiro inteiro digitado pelo usuário e armazene-o na variável x.
// 5. Solicite que o usuário insira o segundo inteiro.
// 6. Leia o segundo inteiro digitado pelo usuário e armazene-o na variável y.
// 7. Solicite que o usuário insira o terceiro inteiro.
// 8. Leia o terceiro inteiro digitado pelo usuário e armazene-o na variável z.
// 9. Compute o produto dos três inteiros contidos nas variáveis x, y e z e atribua o resultado à variável result.
// 19. Use System.out.printf para exibir a mensagem “O valor do produto é” seguida pelo valor da variável result.

// %%
import java.util.Scanner; // importação da classe Scanner do pacote java.util

//public class ex05 {
	//public static void main (String args[]) {
		
        Scanner input = new Scanner(System.in); // prepara entrada de dados
        int x, y, z, result;

		System.out.print("Primeiro inteiro: ");
		x = input.nextInt(); // declaração e inicialização da variável

        System.out.print("Segundo inteiro: ");
        y = input.nextInt(); // declaração e inicialização da variável

        System.out.print("Terceiro inteiro: ");
        z = input.nextInt(); // declaração e inicialização da variável

        result = x * y * z; // calcula produto
        System.out.println("O valor do produto é: " + result); // exibe produto na tela

		//s.close(); // Fecha objeto leitor
	//}	
//}
// Out:
// Primeiro inteiro:
//  2
// Segundo inteiro:
//  3
// Terceiro nteiro:
//  2
// O valor do produto é: 12
// null
